# %% [markdown]
# #Question 1
# <!--Question No-1 Build a simple webpage that displays text as shown in the below image.-->
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Document</title>
# </head>
# <body>
#     <b>This text will be bolded.</b><br><br>
#     <i>This text should be italic.</i><br><br>
#     <u>This text will be underlined.</u><br><br>
#     <mark>This text will bw highlighted.</mark><br><br>
#     This is normal text <sup>This will be super scripted</sup> This is  normal again.<br><br>
#     This is normal text <sub>This will be sub scripted</sub><br><br>
#     Normal text<small> Smal text</small><br><br>
#     <del>This text will be deleded.</del>
# </body>
# </html>

# %% [markdown]
# #Question 2
# <!--Question No-2 % Build a simple webpage that helps users navigate different web development-related websites. Note: On
# clicking the hyperlink the web pages should open in a new tab. Below is a reference image.-->
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Document</title>
# </head>
# <body>
#    <h1>Navigate Me:</h1>
#    Take me to <a href="">PW Skills </a> to buy a course.<br><br>
#    Take me to <a href="">MDN docs</a> to know more about Web development.<br><br>
#    Take me to <a href="">PW Skills Lab</a> to practice ;ive coding.<br>
# </body>
# </html>

# %% [markdown]
# #Question 3 First page
# <!-- Question no-3. Build a simple blog web page with 3 pages home, web development, and web design. Each page must
# contain hyperlinks to other pages in the top, a heading of the page topic and a paragraph of information.
# For the home page you can add some information about yourself-->
#
# <!--This is the first page of the web page-->
#
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Document</title>
#     <style>
#         nav a {
#           margin-right: 15px;
#         }
#       </style>
# </head>
# <body>
#     <nav>
#         <a href="index.html">Home</a>
#         <a href="web dev.html">Web Development</a>
#         <a href="web design.html">Web Design</a>
#       </nav>
#       <h1>Welcome to My Blog</h1>
#     <p>Hi! I'm Amandeep Singh, a passionate web enthusiast learners how to build websites.
#         This blog is my little corner of the internet where
#          I share my thoughts and experiences on web development and design.
#     </p>
# </body>
# </html>

# %% [markdown]
# #Queation 3 Second page
# <!-- Question No-3 This is the second page of the web page.-->
#
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Document</title>
#     <style>
#         nav a {
#           margin-right: 15px;
#         }
#       </style>
# </head>
# <body>
#     <nav>
#         <a href="index.html">Home</a>
#         <a href="web dev.html">Web Development</a>
#         <a href="web design.html">Web Design</a>
#       </nav>
#       <h1>Web Design</h1>
#       <p>Web design focuses on the aesthetics and usability of websites.
#          Good design makes a site attractive and user-friendly,
#          using layout, colors, fonts, and images effectively.
#        </p>
# </body>
# </html>

# %% [markdown]
# #Question 3 Third page
# <!-- Question No-3 This is the Third page of the web page.-->
#
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Document</title>
#     <style>
#     nav a {
#         margin-right: 15px;
#         text-decoration: none;
#       }
#     </style>
# </head>
# <body>
#     <nav>
#         <a href="index.html">Home</a>
#         <a href="web dev.html">Web Development</a>
#         <a href="web design.html">Web Design</a>
#       </nav>
#       <h1>Web Development</h1>
#     <p>Web development is the process of building and maintaining websites.
#         It includes everything from writing code with HTML, CSS, and
#          JavaScript to working with databases and servers.
#     </p>
# </body>
# </html>

# %% [markdown]
# # Question 4
# <!-- Question no-4. Create an ordered list of HTML tags. Each list item must include the tag name and some information about
# the tag-->
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Document</title>
# </head>
# <body>
#     <ol>
#         <li><b>Html=</b>The root element of an HTML page. It wraps all the content.</li>
#         <li><b>Head=</b>Contains meta-information about the document, like title and styles.</li>
#         <li><b>title=</b>Sets the title of the webpage shown in the browser tab.</li>
#         <li><b>Body=</b>Contains the visible content of the webpage like text, images, and links.</li>
#         <li><b>H1 to H6=</b>Heading tags used to define headings, from largest to smallest.</li>
#         <li><b>P=</b>Defines a paragraph of text.</li>
#         <li><b>A=</b>Defines a hyperlink to another page or website using the `href` attribute.</li>
#         <li><b>Img=</b>Embeds an image using the `src` attribute.</li>
#         <li><b>Ul=</b>Creates an unordered (bulleted) list.</li>
#         <li><b>Ol=</b>Creates an ordered (numbered) list.</li>
#         <li><b>Li=</b> Defines a list item inside ol and ul list.</li>
#         <li><b>Div=</b>A generic container used to group and style elements.</li>
#         <li><b>Span=</b>A generic inline container, useful for styling parts of text.</li>
#         <li><b>Br=</b>Inserts a line break.</li>
#         <li><b>Input=</b> Used to create interactive form fields like text boxes, checkboxes, etc.</li>
#     </ol>
# </body>
# </html>

# %% [markdown]
# #Question 5
# <!--Question no-5. Create a description list of full stack web development tech stack, using the <dl> tag.
# Each term should be a tech stack name and each description should be a brief explanation of what the tech stack is used for-->
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Document</title>
# </head>
# <body>
#     <h1>Full Stack Web Development Tech Stack-</h1>
#   <dl>
#     <dt><b>1.HTML-</b></dt>
#     <dd>The standard markup language used to structure content on the web.</dd>
#     <dt><b>2.CSS-</b></dt>
#     <dd>Used to style and layout web pages, including colors, fonts, and responsive design.</dd>
#     <dt><b>3.JavaScript-</b></dt>
#     <dd>A programming language that adds interactivity and dynamic behavior to websites.</dd>
#     <dt><b>4.React-</b></dt>
#     <dd>A JavaScript library for building user interfaces, especially single-page applications.</dd>
#     <dt><b>5.Node.js-</b></dt>
#     <dd>A JavaScript runtime environment that allows developers to build server-side applications using JavaScript.</dd>
#     <dt><b>6.Express.js-</b>/dt>
#     <dd>A lightweight Node.js web framework used to build backend APIs and handle routing.</dd>
#     <dt><b>7.MongoDB-</b></dt>
#     <dd>A NoSQL database that stores data in flexible, JSON-like documents, ideal for modern web apps.</dd>
#     <dt><b>8.Git-</b></dt>
#     <dd>A version control system used to track code changes and collaborate with others.</dd>
#     <dt><b>9.GitHub-</b></dt>
#     <dd>A cloud-based platform for hosting and managing Git repositories.</dd>
#     <dt><b>10.Docker-</b></dt>
#     <dd>A tool for containerizing applications so they can run consistently across different environments.</dd>
#   </dl>
# </body>
# </html>

# %% [markdown]
# #Question 6
# <!--Question No-6 Create an ordered list of the full stack web development tech stack HTML, CSS, and JS. For each tech
# stack, create a table that lists the tech stack name, its primary use cases, and some key features or
# benefits. Below is a reference image.
# -->
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Document</title>
# </head>
# <body>
#     <h3>1. HTML-</h3>
#     <table border="2" cellspacing="5">
#         <tr>
#             <th align="left">Primary use cases</th>
#             <th align="left">Key Features/Benefits</th>
#         </tr>
#         <tr>
#             <td>Building the structure of the web pages</td>
#             <td>
#                 <ul>
#                     <li>Simple and easy to learn.</li>
#                     <li>Compatible with all web browsers.</li>
#                     <li>Allows for the semantic markup.</li>
#                 </ul>
#             </td>
#         </tr>
#     </table>
#     <h3>3. CSS-</h3>
#     <table border="1" cellspacing="4">
#         <tr>
#             <th align="left">Primary use cases</th>
#             <th align="left">Key Features/Benefits.</th>
#         </tr>
#         <tr>
#             <td>Styling and layout of web pages.</td>
#             <td>
#                 <ul>
#                     <li>Allows for seperation of the content and presentation.</li>
#                     <li>Enables responsive design.</li>
#                     <li>Offers a wide range pof styling options.</li>
#                 </ul>
#             </td>
#         </tr>
#     </table>
#     <h3>3. JS-</h3>
#     <table border="1" cellspacing="4">
#         <tr>
#             <th align="left">Primary use cases.</th>
#             <th align="left">Key Features/Benefits</th>
#         </tr>
#         <tr>
#             <td>Adding interactivity and functionality<br>
#                 (e.g., buttons, sliders, forms)</td>
#             <td>
#                 <ul>
#                     <li>Runs in the browsers.</li>
#                     <li>Enables dynamic behaviour.</li>
#                     <li>Work with lobraries and framewworks (e.g., react, Vue)</li>
#                 </ul>
#             </td>
#         </tr>
#     </table>
# </body>
# </html>

# %% [markdown]
# #Question 7
# <!--Question No-7 Build a complex nested list structure representing a multi-level table of contents. Use unordered lists
# (<ul>) and list items (<li>) with inline-block styling to create a structured layout. Apply formatting tags to
# enhance the presentation of list items.-->
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Document</title>
#     <style>
#         body{
#             border: 2px solid #444;
#             padding: 20px;
#             margin: 20px;
#             width: 400px;
#         }
#     </style>
# </head>
# <body class="a">
#     <h2>Table of Contents-</h2>
#     <u>
#     <ul style="color:blueviolet">
#         <li>Part 1: Introducion</li>
#         <li>Part 2: Getting started</li>
#         <ul>
#             <li>2.1 Installing the software</li>
#             <li>2.2 Creating the new project</li>
#             <ul>
#                 <li>2.2.1 Project templates</li>
#                 <li>2.2.2 Customizing the settings</li>
#             </ul>
#         </ul>
#         <ul>
#             <li>2.3 Exploring the Interface</li>
#             <ul>
#                 <li>2.3.1 Toolbar features</li>
#                 <li>2.3.2 Panel layout</li>
#                 <ul>
#                     <li>2.3.2.1 Docking Panels</li>
#                     <li>2.3.2.2 Tabbed Interface</li>
#                 </ul>
#             </ul>
#         </ul>
#         <li>Part 3: Advanced Topics</li>
#         <ul>
#             <li>3.1 Working with plugins</li>
#             <ul>
#                 <li>3.1.1 Installing Plugins</li>
#                 <li>3.1.2 plugin Configuration</li>
#             </ul>
#         </ul>
#         <ul>
#             <li>3.2 Custumizing the UI</li>
#             <ul>
#                 <li>3.2.1 Changing Themes</li>
#                 <li>3.2.2 Configuring Shortcuts</li>
#             </ul>
#         </ul>
#         <ul>
#             <li>3.3 Optimizing Performance</li>
#             <ul>
#                 <li>3.3.1 Caching Strategies</li>
#                 <li>3.3.2 Resource Minification</li>
#             </ul>
#         </ul>
#         <li>Part 4: Conculusion</li>
#     </ul></u>
# </body>
# </html>

# %% [markdown]
# #Question 8
# <!-- Question No-8 Create a table to display a conference schedule. Each row corresponds to a time slot, and each column
# corresponds to a room. Some time slots might have multiple sessions running simultaneously in different
# rooms. Utilize rowspan and colspan attributes as necessary to accommodate this complex schedule.
# (use table attribute “cellpadding”  to give extra padding in each table cell ).
# Assig-->
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Document</title>
#     <style>
#         body{
#             border: 2px solid #444;
#             padding: 20px;
#             margin: 20px;
#             width: 500px;
#         }
#     </style>
# </head>
# <body>
#     <h2>Conference Schedule</h2>
#     <table border="1">
#         <tr>
#             <th>Time</th>
#             <th>Room 1</th>
#             <th>Room 2</th>
#             <th>Room 3</th>
#             <th>Room 4</th>
#         </tr>
#         <tr>
#             <td rowspan="3">9:00 AM - 10:00 AM</td>
#             <td rowspan="2">Keynote</td>
#             <td>Session A</td>
#             <td>Session B</td>
#             <td rowspan="3">Session C</td>
#         </tr>
#         <tr>
#            <td>Session D</td>
#            <td>Session E</td>
#         </tr>
#         <tr>
#         <td>10:30 AM - 11:30 AM</td>
#         <td colspan="2">Session F</td>
#         </tr>
#         <tr>
#             <td>12:00 PM - 2:00 PM</td>
#             <td colspan="4">Lunch Break</td>
#         </tr>
#         <tr>
#             <td rowspan="2">1:00 PM - 2:00 PM</td>
#             <td>Session G</td>
#             <td rowspan="2">Session H</td>
#             <td>Session I</td>
#             <td>Session J</td>
#         </tr>
#         <tr>
#             <td>Session K</td>
#             <td>Session L</td>
#             <td>Session M</td>
#         </tr>
#     </table>
# </body>
# </html>
